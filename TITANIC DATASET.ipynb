# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv('/Users/mohdaffan/Desktop/Titanic-Dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # for the description dataset

# %%
print("Dataset Description :")
print(data.describe)
# Out:
# Dataset Description :
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
print(data.describe(include='all'))
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # for information

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %% [markdown]
# # for value count

# %%
print(data['Survived'].value_counts())
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
print(data['Sex'].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print(data['Pclass'].value_counts())
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
print(data['Age'].value_counts())
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
print(data['SibSp'].value_counts())
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %% [markdown]
# # Set a general style

# %%
sns.set_style('whitegrid')
sns.set_style('darkgrid')
sns.set_style('ticks')
sns.set_style('white')
sns.set_style('dark')

# %% [markdown]
# # Pairplot to see relationships

# %%
print("\nGenerating Pairplot...")
sns.pairplot(data, hue='Survived', diag_kind='kde')
plt.suptitle('Pairplot of Titanic Dataset', y=1.02)
plt.show()
# Out:
# Generating Pairplot...

# %% [markdown]
# # Heatmap of correlations

# %%
# Select only numeric columns
numeric_df = data.select_dtypes(include=['number'])

# Now create heatmap safely
plt.figure(figsize=(10,7))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Histograms for numerical features

# %%
print("\nPlotting Histograms...")
num_cols = ['Age', 'Fare', 'SibSp', 'Parch']
data[num_cols].hist(bins=15, figsize=(15, 6), layout=(2, 2), color='teal')
plt.suptitle('Histograms of Numerical Features')
plt.show()
# Out:
# Plotting Histograms...

# %% [markdown]
# # Boxplots to check outliers

# %%
print("\nPlotting Boxplots...")
plt.figure(figsize=(15,8))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x=data[col], color='lightblue')
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()
# Out:
# Plotting Boxplots...

# %% [markdown]
# # Scatterplots

# %%
print("\nPlotting Scatterplots...")
plt.figure(figsize=(15,8))
# Out:
# Plotting Scatterplots...

# %% [markdown]
# # Scatter Age vs Fare, colored by Survived

# %%
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=data, palette='viridis')
plt.title('Scatterplot of Age vs Fare by Survival')
plt.show()

# %% [markdown]
# # Observations

# %%
print("\nObservations:")
print("""
1. From the Pairplot:
   - There is a slight separation between survived and not survived based on Age and Fare.
   
2. From the Heatmap:
   - 'Fare' and 'Pclass' are moderately correlated.
   - 'Survived' has a notable relationship with 'Pclass', 'Fare', and 'Sex'.
   
3. Histograms:
   - Age is right-skewed, many passengers are young.
   - Fare is heavily right-skewed (few very high fares).
   
4. Boxplots:
   - Several outliers are present, especially in 'Fare' and 'Age'.
   
5. Scatterplot (Age vs Fare):
   - Many younger people with lower fares survived.
   - Very high fares were generally associated with survival.
""")
# Out:
# Observations:
#
# 1. From the Pairplot:
#    - There is a slight separation between survived and not survived based on Age and Fare.
#
# 2. From the Heatmap:
#    - 'Fare' and 'Pclass' are moderately correlated.
#    - 'Survived' has a notable relationship with 'Pclass', 'Fare', and 'Sex'.
#
# 3. Histograms:
#    - Age is right-skewed, many passengers are young.
#    - Fare is heavily right-skewed (few very high fares).
#
# 4. Boxplots:
#    - Several outliers are present, especially in 'Fare' and 'Age'.
#
# 5. Scatterplot (Age vs Fare):
#    - Many younger people with lower fares survived.
#    - Very high fares were generally associated with survival.

# %% [markdown]
# # Summary of Findings

# %%
print("\nSummary of Findings:")
print("""
- Survival rates were higher among females and passengers who paid higher fares.
- First-class passengers (Pclass=1) had a higher survival rate compared to other classes.
- Age influenced survival to some extent; children had higher survival chances.
- 'Fare' and 'Pclass' are important predictors for survival.
""")
# Out:
# Summary of Findings:
#
# - Survival rates were higher among females and passengers who paid higher fares.
# - First-class passengers (Pclass=1) had a higher survival rate compared to other classes.
# - Age influenced survival to some extent; children had higher survival chances.
# - 'Fare' and 'Pclass' are important predictors for survival.
